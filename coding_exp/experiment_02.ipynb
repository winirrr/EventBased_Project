# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = '/Users/winirrr/Documents/EventBased_Project/datasets/dif_duration_dataset_1/11ms/no_press/dvSave-2024_06_25_15_33_29_frame_7.png'
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Threshold the image to create a binary image (white for positive events, black for negative events)
_, binary_image = cv2.threshold(image, 128, 255, cv2.THRESH_BINARY)

# Find contours in the binary image
contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Calculate centroids for each contour
centroids = []
for contour in contours:
    M = cv2.moments(contour)
    if M['m00'] != 0:
        cx = int(M['m10'] / M['m00'])
        cy = int(M['m01'] / M['m00'])
        centroids.append((cx, cy))

# Plot the centroids on the image
centroid_image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
for centroid in centroids:
    cv2.circle(centroid_image, centroid, 2, (0, 0, 255), -1)  # Red color for centroids

# Display the original image with centroids
plt.figure(figsize=(10, 6))
plt.imshow(centroid_image, cmap='gray')
plt.title('Centroids of Events')
plt.show()

# Print centroids for verification
print("Centroids of the events:")
for centroid in centroids:
    print(centroid)
# Out:
# Centroids of the events:
# (624, 478)
# (232, 477)
# (90, 478)
# (94, 477)
# (398, 477)
# (499, 475)
# (565, 475)
# (622, 468)
# (455, 466)
# (222, 466)
# (47, 465)
# (10, 473)
# (528, 463)
# (335, 462)
# (108, 471)
# (240, 458)
# (232, 465)
# (586, 454)
# (337, 456)
# (437, 467)
# (630, 462)
# (296, 452)
# (473, 452)
# (288, 445)
# (45, 453)
# (84, 443)
# (610, 442)
# (278, 443)
# (285, 441)
# (87, 441)
# (472, 444)
# (185, 441)
# (532, 449)
# (289, 439)
# (243, 440)
# (352, 449)
# (270, 437)
# (62, 435)
# (319, 448)
# (282, 438)
# (55, 434)
# (554, 434)
# (197, 444)
# (138, 446)
# (297, 431)
# (291, 430)
# (194, 430)
# (285, 428)
# (597, 440)
# (236, 424)
# (122, 423)
# (402, 438)
# (75, 430)
# (98, 414)
# (503, 421)
# (23, 410)
# (468, 409)
# (273, 408)
# (523, 407)
# (350, 405)
# (302, 406)
# (245, 406)
# (169, 418)
# (373, 406)
# (368, 404)
# (362, 405)
# (565, 416)
# (259, 405)
# (255, 425)
# (336, 402)
# (314, 401)
# (330, 401)
# (321, 403)
# (258, 400)
# (235, 400)
# ...

# %%
len(centroids)
# Out:
# 402

# %%
from sklearn.cluster import KMeans
# inertias = []

# for i in range(1,len(centroids)):
#     kmeans = KMeans(n_clusters=i)
#     kmeans.fit(centroids)
#     inertias.append(kmeans.inertia_)

# plt.plot(range(1,len(centroids)), inertias, marker='o')
# plt.title('Elbow method')
# plt.xlabel('Number of clusters')
# plt.ylabel('Inertia')
# plt.show()

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(centroids)


res = list(zip(*centroids))
plt.scatter(res[0], res[1], c=kmeans.labels_)
plt.show()

# %%
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt

# # Load the image
# image_path_2 = '/Users/winirrr/Documents/EventBased_Project/datasets/dif_duration_dataset_1/11ms/press/dvSave-2024_06_25_15_32_21_frame_85.png'
# image_2 = cv2.imread(image_path_2, cv2.IMREAD_GRAYSCALE)

# # Threshold the image to create a binary image (white for positive events, black for negative events)
# _, binary_image_2 = cv2.threshold(image_2, 128, 255, cv2.THRESH_BINARY)

# # Find contours in the binary image
# contours_2, _ = cv2.findContours(binary_image_2, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# # Calculate centroids for each contour
# centroids_2 = []
# for contour in contours_2:
#     M = cv2.moments(contour)
#     if M['m00'] != 0:
#         cx = int(M['m10'] / M['m00'])
#         cy = int(M['m01'] / M['m00'])
#         centroids.append((cx, cy))

# # Plot the centroids on the image
# centroid_image_2 = cv2.cvtColor(image_2, cv2.COLOR_GRAY2BGR)
# for centroid in centroids_2:
#     cv2.circle(centroid_image_2, centroid, 2, (0, 0, 255), -1)  # Red color for centroids

# # Display the original image with centroids
# plt.figure(figsize=(10, 6))
# plt.imshow(centroid_image_2, cmap='gray')
# plt.title('Centroids of Events')
# plt.show()

# # Print centroids for verification
# print("Centroids of the events:")
# for centroid in centroids_2:
#     print(centroid)

# %%
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt

# # Load the image
# image_path = '/mnt/data/image.png'
# image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# # Threshold the image to create a binary image (white for positive events, black for negative events)
# _, binary_image = cv2.threshold(image, 128, 255, cv2.THRESH_BINARY)

# # Find contours in the binary image
# contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# # Calculate centroids for each contour
# centroids = []
# for contour in contours:
#     M = cv2.moments(contour)
#     if M['m00'] != 0:
#         cx = int(M['m10'] / M['m00'])
#         cy = int(M['m01'] / M['m00'])
#         centroids.append((cx, cy))

# # Get image dimensions
# height, width = image.shape

# # Define sections
# left_section = [c for c in centroids if c[0] < width // 2]
# right_section = [c for c in centroids if c[0] >= width // 2]
# upper_section = [c for c in centroids if c[1] < height // 2]
# lower_section = [c for c in centroids if c[1] >= height // 2]

# # Plot the centroids on the image
# centroid_image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

# # Colors for different sections
# colors = {
#     'left': (255, 0, 0),  # Blue
#     'right': (0, 255, 0),  # Green
#     'upper': (0, 0, 255),  # Red
#     'lower': (255, 255, 0)  # Cyan
# }

# # Plot centroids for each section
# for centroid in left_section:
#     cv2.circle(centroid_image, centroid, 2, colors['left'], -1)
# for centroid in right_section:
#     cv2.circle(centroid_image, centroid, 2, colors['right'], -1)
# for centroid in upper_section:
#     cv2.circle(centroid_image, centroid, 2, colors['upper'], -1)
# for centroid in lower_section:
#     cv2.circle(centroid_image, centroid, 2, colors['lower'], -1)

# # Display the original image with centroids
# plt.figure(figsize=(10, 6))
# plt.imshow(centroid_image)
# plt.title('Centroids of Events in Different Sections')
# plt.show()

# # Print centroids for verification
# print("Centroids of the events in left section:")
# print(left_section)
# print("Centroids of the events in right section:")
# print(right_section)
# print("Centroids of the events in upper section:")
# print(upper_section)
# print("Centroids of the events in lower section:")
# print(lower_section)
